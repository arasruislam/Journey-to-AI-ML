# %%
strings = ['Hello', 'Hi', 'Good', 'Bye', 'Expensive']

with open('../assets/files/sample-2.txt', 'a') as file:
  file.writelines(strings)

# %%
file = open("../assets/files/sample.txt", 'r')
content = file.readlines()
content = list(map(str.strip, content))
print(content)
# Out:
# ['This is a file. Hello AI/ML', 'Another Line']

# %%
with open('../assets/files/test.txt', 'a') as file:
  file.write("Learing AI/ML wit phitron.")
  file.write("I am enjoyin the learing path.")

# %%
with open('../assets/files/test.txt', 'w') as file:
  file.write("Second time attempt\n")
  file.write("Leading goind to fast.")

# %%
with open('../assets/files/test.txt', 'w') as file:
  file.write('Hello test file\n')
  file.write('How is learning going on ?')

# %%
with open('../assets/files/sample.txt', 'r') as file:
  for line in file:
    print(line, end='')
# Out:
# This is a file. Hello AI/ML
# Another Line

# %%
with open("../assets/files/sample.txt", 'r') as file:
  content = file.readlines()
  print(content)

print(file.closed)
# Out:
# ['This is a file. Hello AI/ML\n', 'Another Line\n']
# True

# %%
file = open("../assets/files/sample.txt", 'r')

# content = file.read()
content = file.readlines()

print(file.closed)
# Out:
# False
