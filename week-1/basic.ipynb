# %%
a = 2
print(a)
# Out:
# 2

# %%
b = a
print(b)
print(type(b))
# Out:
# 2
# <class 'int'>

# %%
x = [1, 2, 3, 2, 4]
x.remove(4)
x.pop()
print(x)
# Out:
# [1, 2, 3]

# %%
def welcome_message():
  print("Hello world")

welcome_message()
# Out:
# Hello world
