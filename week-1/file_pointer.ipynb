# %%
with open('../assets/files/sample.txt', 'r') as file:
  print(file.tell()) # initial cursor
  print(file.read(5))
  print(file.tell()) # Ending cursor

  print(file.read())
  file.seek(0)
  print(file.tell())
# Out:
# 0
# Hello
# 5
#  World
#
# 0

# %%
with open('../assets/files/sample.txt', 'r') as file:
  print(file.tell()) # initial cursor
  print(file.read())
  print(file.tell()) # Ending cursor
# Out:
# 0
# Hello World
#
# 12
